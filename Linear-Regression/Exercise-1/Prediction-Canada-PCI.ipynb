# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from pathlib import Path

# %%
file_path = Path.home() / "Desktop/Machine-Learning/Linear-Regression/Exercise-1/canada_per_capita_income.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year, df[['per capita income (US$)']], color='red', marker = '*')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df[['per capita income (US$)']])
# Out:
# LinearRegression()

# %%
prediction = reg.predict([[2020]])
print(prediction)
# Out:
# [[41288.69409442]]
# /home/huppdev28/.local/lib/python3.8/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# %matplotlib inline
plt.xlabel('year', fontsize=20)
plt.ylabel('per capita income (US$)', fontsize=20)
plt.scatter(df.year, df[['per capita income (US$)']], color='red', marker='*')
plt.plot(df.year, df[['per capita income (US$)']])

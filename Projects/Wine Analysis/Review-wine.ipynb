# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight")
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data = pd.read_csv("winemag-data-130k-v2.csv")

# %%
data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
data.sort_values(by = ["price"])
# Out:
#         Unnamed: 0   country  \
# 20484        20484        US
# 112919      112919     Spain
# 59507        59507        US
# 31530        31530        US
# 61768        61768     Spain
# ...            ...       ...
# 129844      129844     Italy
# 129860      129860  Portugal
# 129863      129863  Portugal
# 129893      129893     Italy
# 129964      129964    France
#
#                                               description  \
# 20484   Fruity, soft and rather sweet, this wine smell...
# 112919  Nice on the nose, this has a leafy note and a ...
# 59507   Sweet and fruity, this canned wine feels soft ...
# 31530   Packaged in a cute yellow recyclable Tetrapak,...
# 61768   This opens with standard cherry and berry arom...
# ...                                                   ...
# 129844  Doga delle Clavule is a neutral, mineral-drive...
# 129860  This rich wine has a firm structure as well as...
# 129863  This mature wine that has 50% Touriga Nacional...
# ...

# %%
missing_vals = data["price"].isnull().sum()
print("so there are " + str(missing_vals) + " missing values in price column")
# Out:
# so there are 8996 missing values in price column

# %%
plt.figure(figsize = (16, 5))
sns.lineplot(data = data)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (16, 9))
data["country"].value_counts().head(8).plot.bar()
# Out:
# <Axes: xlabel='country'>

# %%
plt.figure(figsize = (16, 7))
data["points"].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='points'>

# %%
data["price"].value_counts().sort_index().plot.area(
    figsize = (16, 7),
    title = "Price of wine"
)
# Out:
# <Axes: title={'center': 'Price of wine'}, xlabel='price'>

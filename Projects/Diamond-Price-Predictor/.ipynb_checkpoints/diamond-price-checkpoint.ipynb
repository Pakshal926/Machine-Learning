# %%
import pandas as pd

# %%
df = pd.read_csv("diamonds.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df["carat"]
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
ideal_depth_range = (df["depth"] >= 59) & (df["depth"] <= 62.5)
great_cut_diamonds = df[ideal_depth_range & df["cut"].isin(['Ideal', 'Premium'])]

great_cut_diamonds.to_csv("great_cut_diamonds.csv", index=False)
print(great_cut_diamonds.head(100))
# Out:
#      Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 0             1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1             2   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 3             4   0.29  Premium     I     VS2   62.4   58.0    334  4.20
# 12           13   0.22  Premium     F     SI1   60.4   61.0    342  3.88
# 13           14   0.31    Ideal     J     SI2   62.2   54.0    344  4.35
# 14           15   0.20  Premium     E     SI2   60.2   62.0    345  3.79
# 15           16   0.32  Premium     E      I1   60.9   58.0    345  4.38
# 16           17   0.30    Ideal     I     SI2   62.0   54.0    348  4.31
# 26           27   0.24  Premium     I     VS1   62.5   57.0    355  3.97
# 39           40   0.33    Ideal     I     SI2   61.8   55.0    403  4.49
# 40           41   0.33    Ideal     I     SI2   61.2   56.0    403  4.49
# 41           42   0.33    Ideal     J     SI1   61.1   56.0    403  4.49
# ...
